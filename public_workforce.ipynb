# %%
# matplotlib actually has some good documentation...
# https://matplotlib.org/stable/users/explain/quick_start.html#quick-start

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
        
# %reload_ext autoreload
# %autoreload 2

# %%
myhash = {}
myhash['Contact Tracing'] = 13.7
myhash['Vaccination'] = 5.4
myhash['Testing'] = 3.8
myhash['Operational Support'] = 3.2
myhash['Position Restoration'] = 2.7
myhash['Vulnerable Communities'] = 1.3
myhash['PPE'] = 1.0
myhash['Communications'] = 0.5
myhash['Food Insecurity'] = 0.3
print(myhash.keys())
print(myhash.values())
arr_1 = np.array(list(myhash.keys()))
print(arr_1)
arr_2 = np.array(list(myhash.values()))
print(arr_2)

plt.style.use('fivethirtyeight')
plt.tight_layout()
fig, ax = plt.subplots()
ax.set_title('Public Workforce')
ax.set_xlabel('Funds (millions of dollars)')
ax.set_ylabel('Category')
ax.set_ylabel('')
ax.barh(arr_1,arr_2)
# Out:
# dict_keys(['Contact Tracing', 'Vaccination', 'Testing', 'Operational Support', 'Position Restoration', 'Vulnerable Communities', 'PPE', 'Communications', 'Food Insecurity'])
# dict_values([13.7, 5.4, 3.8, 3.2, 2.7, 1.3, 1.0, 0.5, 0.3])
# ['Contact Tracing' 'Vaccination' 'Testing' 'Operational Support'
#  'Position Restoration' 'Vulnerable Communities' 'PPE' 'Communications'
#  'Food Insecurity']
# [13.7  5.4  3.8  3.2  2.7  1.3  1.   0.5  0.3]
# <BarContainer object of 9 artists>
